# %%
import pickle
import torch
import os
import time
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from Gym_Dataset import Gym_Dataset
from torch.utils.data import Dataset

from VAE import VAE
from VAE import VAE_DataSet
from VAE_Trainer import VAE_Trainer

from MDN_RNN import MDN_RNN
from MDN_RNN import MDN_RNN_DataSet
from MDN_RNN_Trainer import MDN_RNN_Trainer

from MDN import MDN
# %matplotlib inline

# %%
dataset_name = "CarRacing-v0_dataset"
dataset_path = "D:\\Implementation_Schmidhuber" +"\\" +dataset_name

vae_trainer = VAE_Trainer(dataset_path,32)
train_loss, bce_loss, kl_loss =  vae_trainer.train(2)

_, axs = plt.subplots(1, 2, figsize=(16, 4))
axs = axs.flatten()
axs[0].plot(range(len(bce_loss)),bce_loss)
axs[1].plot(range(len(kl_loss)),kl_loss)
plt.show()
# Out:
# **** EPOCH 0 ****
# time elapsed: 1561.1823556423187
# ******************
# **** EPOCH 1 ****
# time elapsed: 1528.4826893806458
# ******************

# %%
z = torch.randn(100,32).cuda()
vae_trainer.visualize_sample(z)

# %%
vae_trainer.plot_x_hat(146,440)

# %%
vae_trainer.save_model("D:\\Implementation_Schmidhuber\\vae.pt")
dataset_name = "CarRacing-v0_VAE_Z_dataset"
save_path = "D:\\Implementation_Schmidhuber"+"\\"+dataset_name
vae_trainer.make_z_dataset(save_path)
# Out:
# D:\Implementation_Schmidhuber\VAE_Trainer.py:75: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(eps_data["obs"][0]).cuda()
